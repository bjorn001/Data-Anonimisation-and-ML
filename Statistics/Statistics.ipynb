# %%
# imports

import pandas as pd
from scipy import stats
from scipy.stats import mannwhitneyu

# for creating pair combinations
from itertools import combinations
import seaborn as sns

pd.set_option('display.max_rows', 100)

# %%
df = pd.read_excel('result_data.xlsx', index_col=None)
df.head(5)
# Out:
#       cb_lin   cb_lasso   cb_ridge  mondrian_lin  mondrian_lasso  \
# 0  53.672852  53.497689  53.729505     52.887949       52.887899
# 1  53.055599  52.799154  53.144808     50.619647       50.619737
# 2  52.336882  52.892518  52.820872     50.214292       50.214209
# 3  52.106122  52.611953  52.049599     47.829836       47.829716
# 4  51.648057  51.394093  51.769857     47.207387       47.206748
#
#    mondrian_ridge    ola_lin  ola_ridge  ola_lasso    tdg_lin  tdg_ridge  \
# 0       52.586632  22.994265  22.579093  22.992484  53.501110  52.717343
# 1       50.321428  51.052447  50.730190  51.051379  53.316143  52.357140
# 2       49.891701  52.877610  52.518651  52.876615  52.545893  51.879003
# 3       47.484848  51.961017  51.610548  51.959846  52.121545  52.434886
# 4       46.857136  22.758017  22.386737  22.756592  51.602896  51.257857
#
#    tdg_lasso
# 0  52.947963
# 1  53.367357
# 2  52.639397
# 3  52.390137
# 4  52.310995

# %%
# Stats test
# cb_lin = df['cb_lin']
# cb_lasso = df['cb_lasso']


# stats.ttest_ind(cb_lin, cb_lasso)

# %%
# NULL HYPOTHESIS: distribution is the same

# p value < 0.05 = reject null hypothesis, therefore distribution is NOT the same.
# p value > 0.05 = cannot reject null hypothesis, therefore no proof yet that distribution is not the same.


p_value_list = []
combi1_list = []
combi2_list = []

# Acquiring all possible combinations from the df
all_combinations= list(combinations(df.columns,2))
# Loop through all possible combinations of model and anonymization method result 
for i in all_combinations:
    data=pd.DataFrame(df.loc[:,i])
    result1 = pd.DataFrame(data.iloc[:,[0]])
    result2 = pd.DataFrame(data.iloc[:,[1]])
    
    # Perform the Mann-Whitney u test on each combination
    U1, p = mannwhitneyu(result1, result2, method='exact')
    p_value_list.append(p)
    combi1_list.append(result1.columns.values)
    combi2_list.append(result2.columns.values)



# Cleaning lists
def array_to_list(uncleaned_list):
    cleaned_list = []
    for array in uncleaned_list:
        cleaned_list.append(array.tolist())
        
    return cleaned_list


combi1_list_cleaned = array_to_list(combi1_list)
combi2_list_cleaned = array_to_list(combi2_list)
p_value_list_cleaned = array_to_list(p_value_list)

combi1_list_cleaned = [val for sublist in combi1_list_cleaned for val in sublist]
combi2_list_cleaned = [val for sublist in combi2_list_cleaned for val in sublist]
p_value_list_cleaned = [val for sublist in p_value_list_cleaned for val in sublist]

# Creating a dataframe of all the lists of results 
p_value_df = pd.DataFrame(
    {'combi1': combi1_list_cleaned,
     'combi2': combi2_list_cleaned,
     'p_value': p_value_list_cleaned,
    })

# 1) Printing statistical results of all 66 combinations:
print("Printing all statistical results:")
display(p_value_df)

# For these combinations, the p value is GREATER than 5 which means there is no proof to say that the distributions are DISTINCT. 
# For the rest, which has a p value SMALLER than 5, we can conclude that there is no proof that these distributions are distinct

# 2) Printing all p values larger than 5:
# p_larger_5 = p_value_df[p_value_df['p_value'] > 0.05]
# p_larger_5
# #p_larger_5.to_csv('p_larger_5.csv', index=False)
# display(p_larger_5)
# Out:
# Printing all statistical results:
#             combi1          combi2       p_value
# 0           cb_lin        cb_lasso  9.664417e-01
# 1           cb_lin        cb_ridge  8.102799e-01
# 2           cb_lin    mondrian_lin  3.053225e-03
# 3           cb_lin  mondrian_lasso  3.003502e-03
# 4           cb_lin  mondrian_ridge  1.268759e-03
# 5           cb_lin         ola_lin  9.351722e-23
# 6           cb_lin       ola_ridge  6.328806e-23
# 7           cb_lin       ola_lasso  9.351722e-23
# 8           cb_lin         tdg_lin  3.588598e-02
# 9           cb_lin       tdg_ridge  9.122138e-02
# 10          cb_lin       tdg_lasso  1.443195e-02
# 11        cb_lasso        cb_ridge  8.218125e-01
# 12        cb_lasso    mondrian_lin  3.340300e-03
# 13        cb_lasso  mondrian_lasso  3.340300e-03
# 14        cb_lasso  mondrian_ridge  1.447860e-03
# 15        cb_lasso         ola_lin  8.484133e-23
# 16        cb_lasso       ola_ridge  4.561688e-23
# 17        cb_lasso       ola_lasso  8.484133e-23
# 18        cb_lasso         tdg_lin  4.102935e-02
# 19        cb_lasso       tdg_ridge  9.218014e-02
# 20        cb_lasso       tdg_lasso  1.923179e-02
# 21        cb_ridge    mondrian_lin  3.957198e-03
# 22        cb_ridge  mondrian_lasso  3.957198e-03
# 23        cb_ridge  mondrian_ridge  2.188196e-03
# 24        cb_ridge         ola_lin  8.764157e-23
# 25        cb_ridge       ola_ridge  5.374340e-23
# 26        cb_ridge       ola_lasso  8.764157e-23
# 27        cb_ridge         tdg_lin  2.056106e-02
# 28        cb_ridge       tdg_ridge  4.705767e-02
# 29        cb_ridge       tdg_lasso  8.174394e-03
# 30    mondrian_lin  mondrian_lasso  8.839097e-01
# 31    mondrian_lin  mondrian_ridge  1.614116e-01
# 32    mondrian_lin         ola_lin  1.350400e-14
# 33    mondrian_lin       ola_ridge  5.757047e-17
# 34    mondrian_lin       ola_lasso  1.350400e-14
# 35    mondrian_lin         tdg_lin  5.903031e-05
# 36    mondrian_lin       tdg_ridge  1.823245e-04
# 37    mondrian_lin       tdg_lasso  3.065529e-05
# 38  mondrian_lasso  mondrian_ridge  1.614116e-01
# 39  mondrian_lasso         ola_lin  1.350400e-14
# 40  mondrian_lasso       ola_ridge  5.757047e-17
# 41  mondrian_lasso       ola_lasso  1.350400e-14
# 42  mondrian_lasso         tdg_lin  5.903031e-05
# 43  mondrian_lasso       tdg_ridge  1.823245e-04
# 44  mondrian_lasso       tdg_lasso  3.065529e-05
# 45  mondrian_ridge         ola_lin  1.106131e-12
# 46  mondrian_ridge       ola_ridge  1.851001e-14
# 47  mondrian_ridge       ola_lasso  1.106131e-12
# 48  mondrian_ridge         tdg_lin  1.482642e-05
# 49  mondrian_ridge       tdg_ridge  6.509835e-05
# 50  mondrian_ridge       tdg_lasso  9.667472e-06
# 51         ola_lin       ola_ridge  6.912114e-04
# 52         ola_lin       ola_lasso  1.182856e-01
# 53         ola_lin         tdg_lin  1.135650e-22
# 54         ola_lin       tdg_ridge  8.484133e-23
# 55         ola_lin       tdg_lasso  8.212904e-23
# 56       ola_ridge       ola_lasso  6.912114e-04
# 57       ola_ridge         tdg_lin  6.979475e-23
# 58       ola_ridge       tdg_ridge  5.928536e-23
# 59       ola_ridge       tdg_lasso  4.871132e-23
# 60       ola_lasso         tdg_lin  1.135650e-22
# 61       ola_lasso       tdg_ridge  8.484133e-23
# 62       ola_lasso       tdg_lasso  8.212904e-23
# 63         tdg_lin       tdg_ridge  5.327387e-01
# 64         tdg_lin       tdg_lasso  8.141197e-01
# 65       tdg_ridge       tdg_lasso  3.793660e-01

# %%
# formatting of tables

def color_negative_red(value):
    """
  Colors elements in a dateframe
  green if positive and red if
  negative. Does not color NaN
  values.
  """

    if value < 0:
        color = 'red'
    elif value > 0:
        color = 'green'
    else:
        color = 'black'

    return 'color: %s' % color


# Set CSS properties for th elements in dataframe
th_props = [
  ('font-size', '11px'),
  ('text-align', 'center'),
  ('font-weight', 'bold'),
  ('color', 'black'),
  ('background-color', '#f7f7f9')
  ]

# Set CSS properties for td elements in dataframe
td_props = [
  ('font-size', '11px')
  ]

# Set table styles
styles = [
  dict(selector="th", props=th_props),
  dict(selector="td", props=td_props)
  ]


cm = sns.light_palette("blue", as_cmap=True)

(p_larger_5.style
  .background_gradient(cmap=cm, subset=['p_value'])
  .highlight_max(subset=['p_value'])
  .set_caption('This is a custom caption.')
  .format({'p_value': "{:.2%}"})
  .set_table_styles(styles))

# Set colormap equal to seaborns light green color palette
cm = sns.light_palette("#00FF00", as_cmap=True)

(p_larger_5.style
  .background_gradient(cmap=cm, subset=['p_value'])
  .highlight_max(subset=['p_value'])
  .set_caption('This is a custom caption.')
  .format({'p_value': "{:.2}"})
  .set_table_styles(styles))

#display(p_larger_5)
# Out:
# <style type="text/css">
# #T_9f056 th {
#   font-size: 11px;
#   text-align: center;
#   font-weight: bold;
#   color: black;
#   background-color: #f7f7f9;
# }
# #T_9f056 td {
#   font-size: 11px;
# }
# #T_9f056_row0_col2 {
#   background-color: #00ff00;
#   color: #000000;
#   background-color: yellow;
# }
# #T_9f056_row1_col2 {
#   background-color: #29fd29;
#   color: #000000;
# }
# #T_9f056_row2_col2, #T_9f056_row4_col2 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_9f056_row3_col2 {
#   background-color: #27fd27;
#   color: #000000;
# }
# #T_9f056_row5_col2 {
#   background-color: #16fe16;
#   color: #000000;
# }
# #T_9f056_row6_col2, #T_9f056_row7_col2 {
#   background-color: #d8f4d8;
#   color: #000000;
# }
# #T_9f056_row8_col2 {
#   background-color: #e4f3e4;
#   color: #000000;
# }
# #T_9f056_row9_col2 {
#   background-color: #74f974;
#   color: #000000;
# }
# #T_9f056_row10_col2 {
#   background-color: #28fd28;
#   color: #000000;
# }
# #T_9f056_row11_col2 {
#   background-color: #9df79d;
#   color: #000000;
# }
# </style>
# <table id="T_9f056">
#   <caption>This is a custom caption.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9f056_level0_col0" class="col_heading level0 col0" >combi1</th>
#       <th id="T_9f056_level0_col1" class="col_heading level0 col1" >combi2</th>
#       <th id="T_9f056_level0_col2" class="col_heading level0 col2" >p_value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9f056_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9f056_row0_col0" class="data row0 col0" >cb_lin</td>
#       <td id="T_9f056_row0_col1" class="data row0 col1" >cb_lasso</td>
#       <td id="T_9f056_row0_col2" class="data row0 col2" >0.97</td>
#     </tr>
#     <tr>
#       <th id="T_9f056_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9f056_row1_col0" class="data row1 col0" >cb_lin</td>
#       <td id="T_9f056_row1_col1" class="data row1 col1" >cb_ridge</td>
#       <td id="T_9f056_row1_col2" class="data row1 col2" >0.81</td>
#     </tr>
#     <tr>
#       <th id="T_9f056_level0_row2" class="row_heading level0 row2" >9</th>
#       <td id="T_9f056_row2_col0" class="data row2 col0" >cb_lin</td>
#       <td id="T_9f056_row2_col1" class="data row2 col1" >tdg_ridge</td>
#       <td id="T_9f056_row2_col2" class="data row2 col2" >0.091</td>
#     </tr>
#     <tr>
#       <th id="T_9f056_level0_row3" class="row_heading level0 row3" >11</th>
#       <td id="T_9f056_row3_col0" class="data row3 col0" >cb_lasso</td>
#       <td id="T_9f056_row3_col1" class="data row3 col1" >cb_ridge</td>
#       <td id="T_9f056_row3_col2" class="data row3 col2" >0.82</td>
#     </tr>
#     <tr>
#       <th id="T_9f056_level0_row4" class="row_heading level0 row4" >19</th>
#       <td id="T_9f056_row4_col0" class="data row4 col0" >cb_lasso</td>
#       <td id="T_9f056_row4_col1" class="data row4 col1" >tdg_ridge</td>
#       <td id="T_9f056_row4_col2" class="data row4 col2" >0.092</td>
#     </tr>
#     <tr>
#       <th id="T_9f056_level0_row5" class="row_heading level0 row5" >30</th>
#       <td id="T_9f056_row5_col0" class="data row5 col0" >mondrian_lin</td>
#       <td id="T_9f056_row5_col1" class="data row5 col1" >mondrian_lasso</td>
#       <td id="T_9f056_row5_col2" class="data row5 col2" >0.88</td>
#     </tr>
#     <tr>
#       <th id="T_9f056_level0_row6" class="row_heading level0 row6" >31</th>
#       <td id="T_9f056_row6_col0" class="data row6 col0" >mondrian_lin</td>
#       <td id="T_9f056_row6_col1" class="data row6 col1" >mondrian_ridge</td>
#       <td id="T_9f056_row6_col2" class="data row6 col2" >0.16</td>
#     </tr>
#     <tr>
#       <th id="T_9f056_level0_row7" class="row_heading level0 row7" >38</th>
#       <td id="T_9f056_row7_col0" class="data row7 col0" >mondrian_lasso</td>
#       <td id="T_9f056_row7_col1" class="data row7 col1" >mondrian_ridge</td>
#       <td id="T_9f056_row7_col2" class="data row7 col2" >0.16</td>
#     </tr>
#     <tr>
#       <th id="T_9f056_level0_row8" class="row_heading level0 row8" >52</th>
#       <td id="T_9f056_row8_col0" class="data row8 col0" >ola_lin</td>
#       <td id="T_9f056_row8_col1" class="data row8 col1" >ola_lasso</td>
#       <td id="T_9f056_row8_col2" class="data row8 col2" >0.12</td>
#     </tr>
#     <tr>
#       <th id="T_9f056_level0_row9" class="row_heading level0 row9" >63</th>
#       <td id="T_9f056_row9_col0" class="data row9 col0" >tdg_lin</td>
#       <td id="T_9f056_row9_col1" class="data row9 col1" >tdg_ridge</td>
#       <td id="T_9f056_row9_col2" class="data row9 col2" >0.53</td>
#     </tr>
#     <tr>
#       <th id="T_9f056_level0_row10" class="row_heading level0 row10" >64</th>
#       <td id="T_9f056_row10_col0" class="data row10 col0" >tdg_lin</td>
#       <td id="T_9f056_row10_col1" class="data row10 col1" >tdg_lasso</td>
#       <td id="T_9f056_row10_col2" class="data row10 col2" >0.81</td>
#     </tr>
#     <tr>
#       <th id="T_9f056_level0_row11" class="row_heading level0 row11" >65</th>
#       <td id="T_9f056_row11_col0" class="data row11 col0" >tdg_ridge</td>
#       <td id="T_9f056_row11_col1" class="data row11 col1" >tdg_lasso</td>
#       <td id="T_9f056_row11_col2" class="data row11 col2" >0.38</td>
#     </tr>
#   </tbody>
# </table>

# %%
(p_value_df.style
  .background_gradient(cmap=cm, subset=['p_value'])
  .highlight_max(subset=['p_value'])
  .set_caption('This is a custom caption.')
  .format({'p_value': "{:.2}"})
  .set_table_styles(styles))
# Out:
# <style type="text/css">
# #T_2ba6b th {
#   font-size: 11px;
#   text-align: center;
#   font-weight: bold;
#   color: black;
#   background-color: #f7f7f9;
# }
# #T_2ba6b td {
#   font-size: 11px;
# }
# #T_2ba6b_row0_col2 {
#   background-color: #00ff00;
#   color: #000000;
#   background-color: yellow;
# }
# #T_2ba6b_row1_col2 {
#   background-color: #26fd26;
#   color: #000000;
# }
# #T_2ba6b_row2_col2, #T_2ba6b_row3_col2, #T_2ba6b_row4_col2, #T_2ba6b_row5_col2, #T_2ba6b_row6_col2, #T_2ba6b_row7_col2, #T_2ba6b_row12_col2, #T_2ba6b_row13_col2, #T_2ba6b_row14_col2, #T_2ba6b_row15_col2, #T_2ba6b_row16_col2, #T_2ba6b_row17_col2, #T_2ba6b_row23_col2, #T_2ba6b_row24_col2, #T_2ba6b_row25_col2, #T_2ba6b_row26_col2, #T_2ba6b_row32_col2, #T_2ba6b_row33_col2, #T_2ba6b_row34_col2, #T_2ba6b_row35_col2, #T_2ba6b_row36_col2, #T_2ba6b_row37_col2, #T_2ba6b_row39_col2, #T_2ba6b_row40_col2, #T_2ba6b_row41_col2, #T_2ba6b_row42_col2, #T_2ba6b_row43_col2, #T_2ba6b_row44_col2, #T_2ba6b_row45_col2, #T_2ba6b_row46_col2, #T_2ba6b_row47_col2, #T_2ba6b_row48_col2, #T_2ba6b_row49_col2, #T_2ba6b_row50_col2, #T_2ba6b_row51_col2, #T_2ba6b_row53_col2, #T_2ba6b_row54_col2, #T_2ba6b_row55_col2, #T_2ba6b_row56_col2, #T_2ba6b_row57_col2, #T_2ba6b_row58_col2, #T_2ba6b_row59_col2, #T_2ba6b_row60_col2, #T_2ba6b_row61_col2, #T_2ba6b_row62_col2 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_2ba6b_row8_col2 {
#   background-color: #e2f3e2;
#   color: #000000;
# }
# #T_2ba6b_row9_col2, #T_2ba6b_row19_col2 {
#   background-color: #d4f4d4;
#   color: #000000;
# }
# #T_2ba6b_row10_col2 {
#   background-color: #e8f3e8;
#   color: #000000;
# }
# #T_2ba6b_row11_col2 {
#   background-color: #23fd23;
#   color: #000000;
# }
# #T_2ba6b_row18_col2 {
#   background-color: #e1f3e1;
#   color: #000000;
# }
# #T_2ba6b_row20_col2, #T_2ba6b_row27_col2 {
#   background-color: #e6f3e6;
#   color: #000000;
# }
# #T_2ba6b_row21_col2, #T_2ba6b_row22_col2 {
#   background-color: #eaf3ea;
#   color: #000000;
# }
# #T_2ba6b_row28_col2 {
#   background-color: #e0f4df;
#   color: #000000;
# }
# #T_2ba6b_row29_col2 {
#   background-color: #e9f3e9;
#   color: #000000;
# }
# #T_2ba6b_row30_col2 {
#   background-color: #13fe13;
#   color: #000000;
# }
# #T_2ba6b_row31_col2, #T_2ba6b_row38_col2 {
#   background-color: #c4f5c4;
#   color: #000000;
# }
# #T_2ba6b_row52_col2 {
#   background-color: #cef4ce;
#   color: #000000;
# }
# #T_2ba6b_row63_col2 {
#   background-color: #69fa69;
#   color: #000000;
# }
# #T_2ba6b_row64_col2 {
#   background-color: #25fd25;
#   color: #000000;
# }
# #T_2ba6b_row65_col2 {
#   background-color: #8ff88f;
#   color: #000000;
# }
# </style>
# <table id="T_2ba6b">
#   <caption>This is a custom caption.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2ba6b_level0_col0" class="col_heading level0 col0" >combi1</th>
#       <th id="T_2ba6b_level0_col1" class="col_heading level0 col1" >combi2</th>
#       <th id="T_2ba6b_level0_col2" class="col_heading level0 col2" >p_value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2ba6b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2ba6b_row0_col0" class="data row0 col0" >cb_lin</td>
#       <td id="T_2ba6b_row0_col1" class="data row0 col1" >cb_lasso</td>
#       <td id="T_2ba6b_row0_col2" class="data row0 col2" >0.97</td>
#     </tr>
#     <tr>
#       <th id="T_2ba6b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2ba6b_row1_col0" class="data row1 col0" >cb_lin</td>
#       <td id="T_2ba6b_row1_col1" class="data row1 col1" >cb_ridge</td>
#       <td id="T_2ba6b_row1_col2" class="data row1 col2" >0.81</td>
#     </tr>
#     <tr>
#       <th id="T_2ba6b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2ba6b_row2_col0" class="data row2 col0" >cb_lin</td>
#       <td id="T_2ba6b_row2_col1" class="data row2 col1" >mondrian_lin</td>
#       <td id="T_2ba6b_row2_col2" class="data row2 col2" >0.0031</td>
#     </tr>
#     <tr>
#       <th id="T_2ba6b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2ba6b_row3_col0" class="data row3 col0" >cb_lin</td>
#       <td id="T_2ba6b_row3_col1" class="data row3 col1" >mondrian_lasso</td>
#       <td id="T_2ba6b_row3_col2" class="data row3 col2" >0.003</td>
#     </tr>
#     <tr>
#       <th id="T_2ba6b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2ba6b_row4_col0" class="data row4 col0" >cb_lin</td>
#       <td id="T_2ba6b_row4_col1" class="data row4 col1" >mondrian_ridge</td>
#       <td id="T_2ba6b_row4_col2" class="data row4 col2" >0.0013</td>
#     </tr>
#     <tr>
#       <th id="T_2ba6b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2ba6b_row5_col0" class="data row5 col0" >cb_lin</td>
#       <td id="T_2ba6b_row5_col1" class="data row5 col1" >ola_lin</td>
#       <td id="T_2ba6b_row5_col2" class="data row5 col2" >9.4e-23</td>
#     </tr>
#     <tr>
#       <th id="T_2ba6b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2ba6b_row6_col0" class="data row6 col0" >cb_lin</td>
#       <td id="T_2ba6b_row6_col1" class="data row6 col1" >ola_ridge</td>
#       <td id="T_2ba6b_row6_col2" class="data row6 col2" >6.3e-23</td>
#     </tr>
#     <tr>
#       <th id="T_2ba6b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2ba6b_row7_col0" class="data row7 col0" >cb_lin</td>
#       <td id="T_2ba6b_row7_col1" class="data row7 col1" >ola_lasso</td>
#       <td id="T_2ba6b_row7_col2" class="data row7 col2" >9.4e-23</td>
#     </tr>
#     <tr>
#       <th id="T_2ba6b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_2ba6b_row8_col0" class="data row8 col0" >cb_lin</td>
#       <td id="T_2ba6b_row8_col1" class="data row8 col1" >tdg_lin</td>
#       <td id="T_2ba6b_row8_col2" class="data row8 col2" >0.036</td>
#     </tr>
#     <tr>
#       <th id="T_2ba6b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_2ba6b_row9_col0" class="data row9 col0" >cb_lin</td>
#       <td id="T_2ba6b_row9_col1" class="data row9 col1" >tdg_ridge</td>
#       <td id="T_2ba6b_row9_col2" class="data row9 col2" >0.091</td>
#     </tr>
#     <tr>
#       <th id="T_2ba6b_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_2ba6b_row10_col0" class="data row10 col0" >cb_lin</td>
#       <td id="T_2ba6b_row10_col1" class="data row10 col1" >tdg_lasso</td>
#       <td id="T_2ba6b_row10_col2" class="data row10 col2" >0.014</td>
#     </tr>
#     <tr>
#       <th id="T_2ba6b_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_2ba6b_row11_col0" class="data row11 col0" >cb_lasso</td>
#       <td id="T_2ba6b_row11_col1" class="data row11 col1" >cb_ridge</td>
#       <td id="T_2ba6b_row11_col2" class="data row11 col2" >0.82</td>
#     </tr>
#     <tr>
#       <th id="T_2ba6b_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_2ba6b_row12_col0" class="data row12 col0" >cb_lasso</td>
#       <td id="T_2ba6b_row12_col1" class="data row12 col1" >mondrian_lin</td>
#       <td id="T_2ba6b_row12_col2" class="data row12 col2" >0.0033</td>
#     </tr>
#     <tr>
#       <th id="T_2ba6b_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_2ba6b_row13_col0" class="data row13 col0" >cb_lasso</td>
#       <td id="T_2ba6b_row13_col1" class="data row13 col1" >mondrian_lasso</td>
#       <td id="T_2ba6b_row13_col2" class="data row13 col2" >0.0033</td>
#     </tr>
#     <tr>
#       <th id="T_2ba6b_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_2ba6b_row14_col0" class="data row14 col0" >cb_lasso</td>
#       <td id="T_2ba6b_row14_col1" class="data row14 col1" >mondrian_ridge</td>
#       <td id="T_2ba6b_row14_col2" class="data row14 col2" >0.0014</td>
#     </tr>
#     <tr>
#       <th id="T_2ba6b_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_2ba6b_row15_col0" class="data row15 col0" >cb_lasso</td>
#       <td id="T_2ba6b_row15_col1" class="data row15 col1" >ola_lin</td>
#       <td id="T_2ba6b_row15_col2" class="data row15 col2" >8.5e-23</td>
#     </tr>
#     <tr>
#       <th id="T_2ba6b_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_2ba6b_row16_col0" class="data row16 col0" >cb_lasso</td>
